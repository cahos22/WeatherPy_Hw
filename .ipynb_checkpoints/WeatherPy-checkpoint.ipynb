# %% [markdown]
# Unit 6 | Assignment - What's the Weather Like?
# Background
# Whether financial, political, or social -- data's true power lies in its ability to answer questions definitively. So let's take what you've learned about Python requests, APIs, and JSON traversals to answer a fundamental question: "What's the weather like as we approach the equator?"
#
# Now, we know what you may be thinking: "Duh. It gets hotter..."
#
# But, if pressed, how would you prove it?
#
# Equator
# WeatherPy
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a simple Python library, the OpenWeatherMap API, and a little common sense to create a representative model of weather across world cities.
#
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# 1. Temperature (F) vs. Latitude
# 2. Humidity (%) vs. Latitude
# 3. Cloudiness (%) vs. Latitude
# 4. Wind Speed (mph) vs. Latitude
#
#
# Your final notebook must:
#
# Randomly select at least 500 unique (non-repeat) cities based on latitude and longitude.
# Perform a weather check on each of the cities using a series of successive API calls.
# Include a print log of each city as it's being processed with the city number, city name, and requested URL.
# Save both a CSV of all data retrieved and png images for each scatter plot.
# As final considerations:
#
# You must use the Matplotlib and Seaborn libraries.
# You must include a written description of three observable trends based on the data.
# You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
# You must include an exported markdown version of your Notebook called  README.md in your GitHub repository.
# See Example Solution for a reference on expected format.
# Hints and Considerations
# You may want to start this assignment by refreshing yourself on 4th grade geography, in particular, the geographic coordinate system.
#
# Next, spend the requisite time necessary to study the OpenWeatherMap API. Based on your initial study, you should be able to answer basic questions about the API: Where do you request the API key? Which Weather API in particular will you need? What URL endpoints does it expect? What JSON structure does it respond with? Before you write a line of code, you should be aiming to have a crystal clear understanding of your intended outcome.
#
# Though we've never worked with the citipy Python library, push yourself to decipher how it works, and why it might be relevant. Before you try to incorporate the library into your analysis, start by creating simple test cases outside your main script to confirm that you are using it correctly. Too often, when introduced to a new library, students get bogged down by the most minor of errors -- spending hours investigating their entire code -- when, in fact, a simple and focused test would have shown their basic utilization of the library was wrong from the start. Don't let this be you!
#
# Part of our expectation in this challenge is that you will use critical thinking skills to understand how and why we're recommending the tools we are. What is Citipy for? Why would you use it in conjunction with the OpenWeatherMap API? How would you do so?
#
# In building your script, pay attention to the cities you are using in your query pool. Are you getting coverage of the full gamut of latitudes and longitudes? Or are you simply choosing 500 cities concentrated in one region of the world? Even if you were a geographic genius, simply rattling 500 cities based on your human selection would create a biased dataset. Be thinking of how you should counter this. (Hint: Consider the full range of latitudes).
#
# Lastly, remember -- this is a challenging activity. Push yourself! If you complete this task, then you can safely say that you've gained a strong mastery of the core foundations of data analytics and it will only go better from here. Good luck!

# %%
import requests
import json
import citipy
import random
import pandas as pd
import time
import matplotlib.pyplot as plt
from citipy import citipy
from localenv import api_key

# %matplotlib inline

# api.openweathermap.org/data/2.5/find?q=London

# %%
#function to get the list of cities that will be used to extract weather data
def generate_city_list(number_of_cities):
    cities = []
    lat = 0
    long = 0

    for i in range(number_of_cities):
        lat = round(random.uniform(-90, 90),2)
        long = round(random.uniform(-180, 180),2)
        city = citipy.nearest_city(lat, long)
        if city is not None:
            cities.append(city)
            
    return cities

# %%
#function to get the weather data from the list of cities
def get_weather_data(cities, weather_data, sample_size, counter):
    base_url = "http://api.openweathermap.org/data/2.5/weather?"
    params = {"appid": api_key,
          "q": "",
          "units":"imperial"}
    
    for city in cities:
        counter += 1
        params["q"] = city.city_name
        target_url= f"{base_url}appid={api_key}&units=imperial&q={city.city_name}"
        print(f"Processing Record {counter} of {sample_size} | {city.city_name}")
        print(target_url)
        response = requests.get(target_url).json()
        #response = requests.get(base_url,params=params).json()
        try:
            if (response is not None and response['cod'] == 200):
                weather_data.append(response)
        except Exception as e:
            print(e)
        
        if(counter % 10 == 0):
            time.sleep(5)
    
    return weather_data

# %%
#get the weather data
sample_size = 500
city_list = []
weather_json_l = []

while (len(weather_json_l) < sample_size):
    city_list = generate_city_list(sample_size-len(weather_json_l))  # get the city list
    weather_json_l = get_weather_data(city_list, weather_json_l, sample_size, len(weather_json_l))
    print(f"{len(weather_json_l)}  , {sample_size}")
    
print(len(weather_json_l))
#weather_json_l[0]
# Out:
# Processing Record 1 of 500 | beloha
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=beloha
# Processing Record 2 of 500 | talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=talnakh
# Processing Record 3 of 500 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=dikson
# Processing Record 4 of 500 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=rikitea
# Processing Record 5 of 500 | kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kununurra
# Processing Record 6 of 500 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bathsheba
# Processing Record 7 of 500 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=mar del plata
# Processing Record 8 of 500 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kapaa
# Processing Record 9 of 500 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ilulissat
# Processing Record 10 of 500 | karratha
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=karratha
# Processing Record 11 of 500 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bethel
# Processing Record 12 of 500 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=punta arenas
# Processing Record 13 of 500 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=vaini
# Processing Record 14 of 500 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hilo
# Processing Record 15 of 500 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=iqaluit
# Processing Record 16 of 500 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=chokurdakh
# Processing Record 17 of 500 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=butaritari
# Processing Record 18 of 500 | ngunguru
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ngunguru
# Processing Record 19 of 500 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=marsh harbour
# Processing Record 20 of 500 | yulara
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=yulara
# Processing Record 21 of 500 | vestmanna
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=vestmanna
# Processing Record 22 of 500 | korla
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=korla
# Processing Record 23 of 500 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=katsuura
# Processing Record 24 of 500 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=castro
# Processing Record 25 of 500 | alofi
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=alofi
# Processing Record 26 of 500 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=nikolskoye
# Processing Record 27 of 500 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=castro
# Processing Record 28 of 500 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=cape town
# Processing Record 29 of 500 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=busselton
# Processing Record 30 of 500 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=grand river south east
# Processing Record 31 of 500 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=olafsvik
# Processing Record 32 of 500 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=rikitea
# Processing Record 33 of 500 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=taolanaro
# Processing Record 34 of 500 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hithadhoo
# Processing Record 35 of 500 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=belushya guba
# Processing Record 36 of 500 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hithadhoo
# Processing Record 37 of 500 | buala
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=buala
# Processing Record 38 of 500 | mae hong son
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=mae hong son
# Processing Record 39 of 500 | troitskiy
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=troitskiy
# Processing Record 40 of 500 | fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=fortuna
# Processing Record 41 of 500 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kapaa
# Processing Record 42 of 500 | chachapoyas
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=chachapoyas
# Processing Record 43 of 500 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=yellowknife
# Processing Record 44 of 500 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hilo
# Processing Record 45 of 500 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=atuona
# Processing Record 46 of 500 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=vaini
# Processing Record 47 of 500 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=coquimbo
# Processing Record 48 of 500 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=puerto ayora
# Processing Record 49 of 500 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kapaa
# Processing Record 50 of 500 | bubaque
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bubaque
# Processing Record 51 of 500 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=punta arenas
# Processing Record 52 of 500 | ardmore
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ardmore
# Processing Record 53 of 500 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=busselton
# Processing Record 54 of 500 | marienburg
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=marienburg
# Processing Record 55 of 500 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=mataura
# Processing Record 56 of 500 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ushuaia
# Processing Record 57 of 500 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=puerto ayora
# Processing Record 58 of 500 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=cape town
# Processing Record 59 of 500 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=arraial do cabo
# Processing Record 60 of 500 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hobart
# Processing Record 61 of 500 | ashtian
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ashtian
# Processing Record 62 of 500 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=mataura
# Processing Record 63 of 500 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hobart
# Processing Record 64 of 500 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=castro
# Processing Record 65 of 500 | wodonga
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=wodonga
# Processing Record 66 of 500 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=mys shmidta
# Processing Record 67 of 500 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=avarua
# Processing Record 68 of 500 | hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hambantota
# Processing Record 69 of 500 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=lavrentiya
# Processing Record 70 of 500 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=havre-saint-pierre
# Processing Record 71 of 500 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=albany
# Processing Record 72 of 500 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=atuona
# Processing Record 73 of 500 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tilichiki
# Processing Record 74 of 500 | tbilisskaya
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tbilisskaya
# Processing Record 75 of 500 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=luderitz
# Processing Record 76 of 500 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=busselton
# Processing Record 77 of 500 | vestmanna
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=vestmanna
# Processing Record 78 of 500 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=avarua
# Processing Record 79 of 500 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=srednekolymsk
# Processing Record 80 of 500 | harwich
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=harwich
# Processing Record 81 of 500 | aloleng
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=aloleng
# Processing Record 82 of 500 | sigerfjord
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=sigerfjord
# Processing Record 83 of 500 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=clyde river
# Processing Record 84 of 500 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=leningradskiy
# Processing Record 85 of 500 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=rikitea
# Processing Record 86 of 500 | kahului
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kahului
# Processing Record 87 of 500 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=saint george
# Processing Record 88 of 500 | kiunga
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kiunga
# Processing Record 89 of 500 | aswan
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=aswan
# Processing Record 90 of 500 | buckeye
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=buckeye
# Processing Record 91 of 500 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=yerbogachen
# Processing Record 92 of 500 | verkhnetulomskiy
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=verkhnetulomskiy
# Processing Record 93 of 500 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=busselton
# Processing Record 94 of 500 | ratnagiri
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ratnagiri
# Processing Record 95 of 500 | magnitka
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=magnitka
# Processing Record 96 of 500 | nador
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=nador
# Processing Record 97 of 500 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bambous virieux
# Processing Record 98 of 500 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ancud
# Processing Record 99 of 500 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ilulissat
# Processing Record 100 of 500 | nemuro
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=nemuro
# Processing Record 101 of 500 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=barrow
# Processing Record 102 of 500 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=pevek
# Processing Record 103 of 500 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=esperance
# Processing Record 104 of 500 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=cape town
# Processing Record 105 of 500 | port moresby
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=port moresby
# Processing Record 106 of 500 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=attawapiskat
# Processing Record 107 of 500 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=port elizabeth
# Processing Record 108 of 500 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=cape town
# Processing Record 109 of 500 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=punta arenas
# Processing Record 110 of 500 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=taolanaro
# Processing Record 111 of 500 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bathsheba
# Processing Record 112 of 500 | hearst
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hearst
# Processing Record 113 of 500 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=busselton
# Processing Record 114 of 500 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=souillac
# Processing Record 115 of 500 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=butaritari
# Processing Record 116 of 500 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=port alfred
# Processing Record 117 of 500 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=albany
# Processing Record 118 of 500 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tasiilaq
# Processing Record 119 of 500 | banmo
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=banmo
# Processing Record 120 of 500 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=butaritari
# Processing Record 121 of 500 | isangel
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=isangel
# Processing Record 122 of 500 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=mahebourg
# Processing Record 123 of 500 | chicama
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=chicama
# Processing Record 124 of 500 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hobart
# Processing Record 125 of 500 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=cockburn town
# Processing Record 126 of 500 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ushuaia
# Processing Record 127 of 500 | hatillo
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hatillo
# Processing Record 128 of 500 | shimoda
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=shimoda
# Processing Record 129 of 500 | tradate
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tradate
# Processing Record 130 of 500 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=illoqqortoormiut
# Processing Record 131 of 500 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tuktoyaktuk
# Processing Record 132 of 500 | dalbandin
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=dalbandin
# Processing Record 133 of 500 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ushuaia
# Processing Record 134 of 500 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tumannyy
# Processing Record 135 of 500 | bilibino
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bilibino
# Processing Record 136 of 500 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=airai
# Processing Record 137 of 500 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=lebu
# Processing Record 138 of 500 | muhos
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=muhos
# Processing Record 139 of 500 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=victoria
# Processing Record 140 of 500 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=clyde river
# Processing Record 141 of 500 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ushuaia
# Processing Record 142 of 500 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=berdigestyakh
# Processing Record 143 of 500 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=rikitea
# Processing Record 144 of 500 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=vaini
# Processing Record 145 of 500 | khuzdar
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=khuzdar
# Processing Record 146 of 500 | general pico
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=general pico
# Processing Record 147 of 500 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kapaa
# Processing Record 148 of 500 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=busselton
# Processing Record 149 of 500 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=rikitea
# Processing Record 150 of 500 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hermanus
# Processing Record 151 of 500 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=mataura
# Processing Record 152 of 500 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=albany
# Processing Record 153 of 500 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=new norfolk
# Processing Record 154 of 500 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hermanus
# Processing Record 155 of 500 | nadvoitsy
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=nadvoitsy
# Processing Record 156 of 500 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=avarua
# Processing Record 157 of 500 | carutapera
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=carutapera
# Processing Record 158 of 500 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=albany
# Processing Record 159 of 500 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=avarua
# Processing Record 160 of 500 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=busselton
# Processing Record 161 of 500 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=cabo san lucas
# Processing Record 162 of 500 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=rikitea
# Processing Record 163 of 500 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=albany
# Processing Record 164 of 500 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=whitehorse
# Processing Record 165 of 500 | huarmey
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=huarmey
# Processing Record 166 of 500 | woodstock
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=woodstock
# Processing Record 167 of 500 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=cayenne
# Processing Record 168 of 500 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ushuaia
# Processing Record 169 of 500 | tautira
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tautira
# Processing Record 170 of 500 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=belushya guba
# Processing Record 171 of 500 | sorland
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=sorland
# Processing Record 172 of 500 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=punta arenas
# Processing Record 173 of 500 | christchurch
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=christchurch
# Processing Record 174 of 500 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=provideniya
# Processing Record 175 of 500 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=qaqortoq
# Processing Record 176 of 500 | lolua
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=lolua
# Processing Record 177 of 500 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ushuaia
# Processing Record 178 of 500 | tekirdag
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tekirdag
# Processing Record 179 of 500 | namibe
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=namibe
# Processing Record 180 of 500 | kiruna
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kiruna
# Processing Record 181 of 500 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=port elizabeth
# Processing Record 182 of 500 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=punta arenas
# Processing Record 183 of 500 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=lompoc
# Processing Record 184 of 500 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=rikitea
# Processing Record 185 of 500 | tarakan
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tarakan
# Processing Record 186 of 500 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=butaritari
# Processing Record 187 of 500 | antalaha
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=antalaha
# Processing Record 188 of 500 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=albany
# Processing Record 189 of 500 | colonia
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=colonia
# Processing Record 190 of 500 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=cape town
# Processing Record 191 of 500 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=nikolskoye
# Processing Record 192 of 500 | bilma
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bilma
# Processing Record 193 of 500 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=victoria
# Processing Record 194 of 500 | dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=dunedin
# Processing Record 195 of 500 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=rikitea
# Processing Record 196 of 500 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hobart
# Processing Record 197 of 500 | ust-maya
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ust-maya
# Processing Record 198 of 500 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=albany
# Processing Record 199 of 500 | yulara
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=yulara
# Processing Record 200 of 500 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=albany
# Processing Record 201 of 500 | sistranda
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=sistranda
# Processing Record 202 of 500 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=upernavik
# Processing Record 203 of 500 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=illoqqortoormiut
# Processing Record 204 of 500 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tuktoyaktuk
# Processing Record 205 of 500 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=lebu
# Processing Record 206 of 500 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=baruun-urt
# Processing Record 207 of 500 | sataua
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=sataua
# Processing Record 208 of 500 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=taolanaro
# Processing Record 209 of 500 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=barentsburg
# Processing Record 210 of 500 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=saskylakh
# Processing Record 211 of 500 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=avarua
# Processing Record 212 of 500 | hofn
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hofn
# Processing Record 213 of 500 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=souillac
# Processing Record 214 of 500 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=guerrero negro
# Processing Record 215 of 500 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=avarua
# Processing Record 216 of 500 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=souillac
# Processing Record 217 of 500 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=torbay
# Processing Record 218 of 500 | bongouanou
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bongouanou
# Processing Record 219 of 500 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hobart
# Processing Record 220 of 500 | ucluelet
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ucluelet
# Processing Record 221 of 500 | placido de castro
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=placido de castro
# Processing Record 222 of 500 | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kavieng
# Processing Record 223 of 500 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=beringovskiy
# Processing Record 224 of 500 | angoche
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=angoche
# Processing Record 225 of 500 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hobart
# Processing Record 226 of 500 | tocopilla
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tocopilla
# Processing Record 227 of 500 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=barrow
# Processing Record 228 of 500 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ilulissat
# Processing Record 229 of 500 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=souillac
# Processing Record 230 of 500 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=port alfred
# Processing Record 231 of 500 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=punta arenas
# Processing Record 232 of 500 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ushuaia
# Processing Record 233 of 500 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=mataura
# Processing Record 234 of 500 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=port alfred
# Processing Record 235 of 500 | waldoboro
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=waldoboro
# Processing Record 236 of 500 | deep river
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=deep river
# Processing Record 237 of 500 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=vaini
# Processing Record 238 of 500 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=san cristobal
# Processing Record 239 of 500 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=barrow
# Processing Record 240 of 500 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=esperance
# Processing Record 241 of 500 | ho
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ho
# Processing Record 242 of 500 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hilo
# Processing Record 243 of 500 | mzimba
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=mzimba
# Processing Record 244 of 500 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=vaini
# Processing Record 245 of 500 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=chokurdakh
# Processing Record 246 of 500 | malangali
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=malangali
# Processing Record 247 of 500 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ushuaia
# Processing Record 248 of 500 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=nizhneyansk
# Processing Record 249 of 500 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=taolanaro
# Processing Record 250 of 500 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bambous virieux
# Processing Record 251 of 500 | tortoli
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tortoli
# Processing Record 252 of 500 | touros
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=touros
# Processing Record 253 of 500 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=busselton
# Processing Record 254 of 500 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=punta arenas
# Processing Record 255 of 500 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=atuona
# Processing Record 256 of 500 | kalemie
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kalemie
# Processing Record 257 of 500 | saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=saldanha
# Processing Record 258 of 500 | kisangani
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kisangani
# Processing Record 259 of 500 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=puerto ayora
# Processing Record 260 of 500 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=pangnirtung
# Processing Record 261 of 500 | salalah
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=salalah
# Processing Record 262 of 500 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=khatanga
# Processing Record 263 of 500 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=cherskiy
# Processing Record 264 of 500 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=butaritari
# Processing Record 265 of 500 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hobart
# Processing Record 266 of 500 | emerald
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=emerald
# Processing Record 267 of 500 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=busselton
# Processing Record 268 of 500 | viedma
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=viedma
# Processing Record 269 of 500 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bredasdorp
# Processing Record 270 of 500 | kapit
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kapit
# Processing Record 271 of 500 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=saskylakh
# Processing Record 272 of 500 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kavaratti
# Processing Record 273 of 500 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=cape town
# Processing Record 274 of 500 | alofi
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=alofi
# Processing Record 275 of 500 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=chuy
# Processing Record 276 of 500 | si sa ket
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=si sa ket
# Processing Record 277 of 500 | kurchum
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kurchum
# Processing Record 278 of 500 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bambous virieux
# Processing Record 279 of 500 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tiksi
# Processing Record 280 of 500 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kapaa
# Processing Record 281 of 500 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=busselton
# Processing Record 282 of 500 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=souillac
# Processing Record 283 of 500 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=punta arenas
# Processing Record 284 of 500 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=coquimbo
# Processing Record 285 of 500 | clinton
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=clinton
# Processing Record 286 of 500 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=port alfred
# Processing Record 287 of 500 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kodiak
# Processing Record 288 of 500 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=yellowknife
# Processing Record 289 of 500 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=rikitea
# Processing Record 290 of 500 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=avarua
# Processing Record 291 of 500 | telimele
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=telimele
# Processing Record 292 of 500 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=norman wells
# Processing Record 293 of 500 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=chokurdakh
# Processing Record 294 of 500 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bredasdorp
# Processing Record 295 of 500 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=rikitea
# Processing Record 296 of 500 | akhmeta
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=akhmeta
# Processing Record 297 of 500 | teguldet
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=teguldet
# Processing Record 298 of 500 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=qaanaaq
# Processing Record 299 of 500 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ponta do sol
# Processing Record 300 of 500 | zaykovo
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=zaykovo
# Processing Record 301 of 500 | maridi
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=maridi
# Processing Record 302 of 500 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=cape town
# Processing Record 303 of 500 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=leningradskiy
# Processing Record 304 of 500 | acapulco
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=acapulco
# Processing Record 305 of 500 | lakes entrance
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=lakes entrance
# Processing Record 306 of 500 | mumford
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=mumford
# Processing Record 307 of 500 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kavaratti
# Processing Record 308 of 500 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=sao joao da barra
# Processing Record 309 of 500 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hobart
# Processing Record 310 of 500 | puertollano
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=puertollano
# Processing Record 311 of 500 | milkovo
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=milkovo
# Processing Record 312 of 500 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hermanus
# Processing Record 313 of 500 | bedesa
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bedesa
# Processing Record 314 of 500 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tuktoyaktuk
# Processing Record 315 of 500 | punta arenas
# ...
# Processing Record 433 of 500 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hobart
# Processing Record 434 of 500 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hilo
# Processing Record 435 of 500 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=cape town
# Processing Record 436 of 500 | el badari
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=el badari
# Processing Record 437 of 500 | margate
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=margate
# Processing Record 438 of 500 | gaspe
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=gaspe
# Processing Record 439 of 500 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=thompson
# Processing Record 440 of 500 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bredasdorp
# Processing Record 441 of 500 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=rikitea
# Processing Record 442 of 500 | zhangye
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=zhangye
# Processing Record 443 of 500 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=albany
# Processing Record 444 of 500 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=new norfolk
# Processing Record 445 of 500 | alakurtti
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=alakurtti
# Processing Record 446 of 500 | arlit
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=arlit
# Processing Record 447 of 500 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=thompson
# Processing Record 448 of 500 | anloga
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=anloga
# Processing Record 449 of 500 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=san cristobal
# Processing Record 450 of 500 | strezhevoy
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=strezhevoy
# Processing Record 451 of 500 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=butaritari
# Processing Record 452 of 500 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=luderitz
# Processing Record 453 of 500 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=saint-joseph
# Processing Record 454 of 500 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tasiilaq
# Processing Record 455 of 500 | mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=mehamn
# Processing Record 456 of 500 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ponta do sol
# Processing Record 457 of 500 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=nikolskoye
# Processing Record 458 of 500 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=busselton
# Processing Record 459 of 500 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=barrow
# Processing Record 460 of 500 | tanete
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tanete
# Processing Record 461 of 500 | kahului
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kahului
# Processing Record 462 of 500 | high rock
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=high rock
# Processing Record 463 of 500 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=jamestown
# Processing Record 464 of 500 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=barentsburg
# Processing Record 465 of 500 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tuktoyaktuk
# Processing Record 466 of 500 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=saint-philippe
# Processing Record 467 of 500 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ponta do sol
# Processing Record 468 of 500 | bom sucesso
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bom sucesso
# Processing Record 469 of 500 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=qaanaaq
# Processing Record 470 of 500 | dingle
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=dingle
# Processing Record 471 of 500 | xinxiang
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=xinxiang
# Processing Record 472 of 500 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=vaini
# Processing Record 473 of 500 | ukiah
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ukiah
# Processing Record 474 of 500 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=punta arenas
# Processing Record 475 of 500 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=louisbourg
# Processing Record 476 of 500 | richards bay
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=richards bay
# Processing Record 477 of 500 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bathsheba
# Processing Record 478 of 500 | fare
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=fare
# Processing Record 479 of 500 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ushuaia
# Processing Record 480 of 500 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=cayenne
# Processing Record 481 of 500 | boa vista
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=boa vista
# Processing Record 482 of 500 | kirakira
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kirakira
# Processing Record 483 of 500 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=punta arenas
# Processing Record 484 of 500 | sumkino
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=sumkino
# Processing Record 485 of 500 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=east london
# Processing Record 486 of 500 | broome
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=broome
# Processing Record 487 of 500 | huarmey
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=huarmey
# Processing Record 488 of 500 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=chuy
# Processing Record 489 of 500 | milkovo
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=milkovo
# Processing Record 490 of 500 | leninskoye
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=leninskoye
# Processing Record 491 of 500 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hobart
# Processing Record 492 of 500 | sunrise manor
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=sunrise manor
# Processing Record 493 of 500 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=saint-augustin
# Processing Record 494 of 500 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=esperance
# Processing Record 495 of 500 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ushuaia
# Processing Record 496 of 500 | kuytun
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kuytun
# Processing Record 497 of 500 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=taolanaro
# Processing Record 498 of 500 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=umzimvubu
# Processing Record 499 of 500 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=saint george
# Processing Record 500 of 500 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bethel
# 467  , 500
# Processing Record 468 of 500 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=punta arenas
# Processing Record 469 of 500 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=port alfred
# Processing Record 470 of 500 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=half moon bay
# Processing Record 471 of 500 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kodiak
# Processing Record 472 of 500 | houma
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=houma
# Processing Record 473 of 500 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=mataura
# Processing Record 474 of 500 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=saint-philippe
# Processing Record 475 of 500 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=nanortalik
# Processing Record 476 of 500 | amilly
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=amilly
# Processing Record 477 of 500 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hermanus
# Processing Record 478 of 500 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=barrow
# Processing Record 479 of 500 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=saint-francois
# Processing Record 480 of 500 | moose factory
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=moose factory
# Processing Record 481 of 500 | kattivakkam
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kattivakkam
# Processing Record 482 of 500 | vardo
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=vardo
# Processing Record 483 of 500 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=hermanus
# Processing Record 484 of 500 | bremen
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=bremen
# Processing Record 485 of 500 | shuya
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=shuya
# Processing Record 486 of 500 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=butaritari
# Processing Record 487 of 500 | necochea
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=necochea
# Processing Record 488 of 500 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=vaitupu
# Processing Record 489 of 500 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=cape town
# Processing Record 490 of 500 | kamina
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=kamina
# Processing Record 491 of 500 | asyut
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=asyut
# Processing Record 492 of 500 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=leningradskiy
# Processing Record 493 of 500 | mariinsk
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=mariinsk
# Processing Record 494 of 500 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=atuona
# Processing Record 495 of 500 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=ribeira grande
# Processing Record 496 of 500 | montepuez
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=montepuez
# Processing Record 497 of 500 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=tuktoyaktuk
# Processing Record 498 of 500 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=albany
# Processing Record 499 of 500 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=nizhneyansk
# Processing Record 500 of 500 | berlevag
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=berlevag
# 498  , 500
# Processing Record 499 of 500 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=busselton
# Processing Record 500 of 500 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=mys shmidta
# 499  , 500
# Processing Record 500 of 500 | lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=e23b8b0de428efa9ed43081cb6f04a77&units=imperial&q=lorengau
# 500  , 500
# 500

# %%
print(weather_json_l[15])
# Out:
# {'coord': {'lon': 147.9, 'lat': 70.62}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': -23.8, 'pressure': 1037.04, 'humidity': 36, 'temp_min': -23.8, 'temp_max': -23.8, 'sea_level': 1039.45, 'grnd_level': 1037.04}, 'wind': {'speed': 3.71, 'deg': 46.0025}, 'clouds': {'all': 36}, 'dt': 1520245319, 'sys': {'message': 0.0045, 'country': 'RU', 'sunrise': 1520198360, 'sunset': 1520234539}, 'id': 2126123, 'name': 'Chokurdakh', 'cod': 200}

# %%
# Extract interesting data from responses
city_names = [data.get("name") for data in weather_json_l]
country_data = [data.get("sys").get("country") for data in weather_json_l]
date_data = [data.get("dt") for data in weather_json_l]
lat_data = [data.get("coord").get("lat") for data in weather_json_l]
temp_data = [data.get("main").get("temp_max") for data in weather_json_l]
humidity_data =[data.get("main").get("humidity") for data in weather_json_l]
cloudiness_data = [data.get("clouds").get("all") for data in weather_json_l]
wind_speed_data = [data.get("wind").get("speed") for data in weather_json_l]

weather_dict = {"City":city_names, "Country" : country_data,
                "Date" : date_data, "Latitude": lat_data, 
                "Max Temp": temp_data, "Humidity" : humidity_data,
                "Cloudiness": temp_data, "Wind Speed (mph)" : humidity_data}
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity  Latitude  Max Temp  \
# 0     Beloha       89.61      MG  1520245307        48    -25.17     89.61
# 1    Talnakh      -15.25      RU  1520245308        68     69.49    -15.25
# 2     Dikson       -5.66      RU  1520245308       100     73.51     -5.66
# 3    Rikitea       80.16      PF  1520245309       100    -23.12     80.16
# 4  Kununurra       84.20      AU  1520244000        74    -15.77     84.20
#
#    Wind Speed (mph)
# 0                48
# 1                68
# 2               100
# 3               100
# 4                74

# %%
#Saving to CSV
weather_df.to_csv("WeatherPyData.csv",index=False)

# %%
#Plotting  Temperature vs Latitude
ax1 = weather_df.plot(kind="scatter",
                x="Latitude", 
                y="Max Temp",
                marker="o",
                title="City Latitude vs. Max Temperature (03/01/18)",
                grid=True
               )

ax1.set_ylabel("Max Temperature (F)")
fig = ax1.get_figure()

fig.savefig("TemperaturevsLatitude.png");

# %%
#Plotting % Humidity vs Latitude
ax2 = weather_df.plot(kind="scatter",
                x="Latitude", 
                y="Humidity",
                marker="o",
                title="City Latitude vs. Humidity (03/01/18)",
                grid=True
               )

ax2.set_ylabel("Humidity (%)")
fig = ax2.get_figure()
fig.savefig("HumidityvsLatitude.png");

# %%
#Plotting % Cloudiness vs Latitude
ax3 = weather_df.plot(kind="scatter",
                x="Latitude", 
                y="Cloudiness",
                marker="o",
                title="City Latitude vs. Cloudiness(03/01/18)",
                grid=True
               )

ax3.set_ylabel("Cloudiness (%)")
fig = ax3.get_figure()
fig.savefig("CloudinessvsLatitude.png");

# %%
#Plotting % Humidity vs Latitude
ax4 = weather_df.plot(kind="scatter",
                x="Latitude", 
                y="Wind Speed (mph)",
                marker="o",
                title="City Latitude vs. Wind Speed(03/01/18)",
                grid=True
               );

fig = ax4.get_figure()
fig.savefig("WindSpeedvsLatitude.png");
